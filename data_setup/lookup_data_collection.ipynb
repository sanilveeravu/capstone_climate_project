# %%
import pandas as pd

# %%
countries_df = pd.read_csv("../data/lookup_data/countries.csv")
countries_df.head()
# Out:
#   country_code           country_name
# 0           AC   Antigua and Barbuda
# 1           AE  United Arab Emirates
# 2           AF            Afghanistan
# 3           AG               Algeria
# 4           AJ            Azerbaijan

# %%
states_df = pd.read_csv("../data/lookup_data/states.csv")
states_df.head()
# Out:
#   state_code                                       state_name
# 0         AB                                          ALBERTA
# 1         AK                                           ALASKA
# 2         AL  ALABAMA
# 3         AR                                         ARKANSAS
# 4         AS                                   AMERICAN SAMOA

# %%
colspecs = [(0, 11), (13, 20), (22, 30), (32, 37), (38, 40), (41, -1)]
stations_df = pd.read_fwf('../data/lookup_data/station_state_city.txt', colspecs=colspecs, names=['station_id', 'latitude', 'longitude', 'elevation', 'state_code', 'station_name'])


stations_df.head(10)
# Out:
#     station_id  latitude  longitude  elevation state_code  \
# 0  US009052008   43.7333   -96.6333      482.0         SD
# 1  US10RMHS145   40.5268   105.1113      569.1         CO
# 2  US10adam001   40.5680   -98.5069      598.0         NE
# 3  US10adam002   40.5093   -98.5493      601.1         NE
# 4  US10adam003   40.4663   -98.6537      615.1         NE
# 5  US10adam004   40.4798   -98.4026      570.0         NE
# 6  US10adam006   40.4372   -98.5912      601.1         NE
# 7  US10adam007   40.5389   -98.4713      588.9         NE
# 8  US10adam008   40.4953   -98.2973      566.9         NE
# 9  US10adam010   40.5532   -98.6297      622.1         NE
#
#                     station_name
# 0  SIOUX FALLS (ENVIRON. CANADA)
# 1                   RMHS 1.6 SSW
# 2                  JUNIATA 1.5 S
# 3                JUNIATA 6.0 SSW
# 4                HOLSTEIN 0.1 NW
# 5                     AYR 3.5 NE
# 6                ROSELAND 2.8 SW
# 7               HASTINGS 5.4 WSW
# ...

# %%
stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68512 entries, 0 to 68511
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_id    68512 non-null  object
#  1   latitude      68512 non-null  float64
#  2   longitude     68512 non-null  float64
#  3   elevation     68512 non-null  float64
#  4   state_code    68512 non-null  object
#  5   station_name  68512 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 3.1+ MB

# %%
stations_lookup_df = pd.merge(stations_df, states_df, on=["state_code", "state_code"])
stations_lookup_df.head()
# Out:
#     station_id  latitude  longitude  elevation state_code  \
# 0  US009052008   43.7333   -96.6333      482.0         SD
# 1  US1SDAR0001   43.6320   -98.4828      481.6         SD
# 2  US1SDAR0002   43.5863   -98.4356      504.1         SD
# 3  US1SDAR0003   43.5715   -98.7424      494.4         SD
# 4  US1SDAR0004   43.5130   -98.4630      493.5         SD
#
#                     station_name    state_name
# 0  SIOUX FALLS (ENVIRON. CANADA)  SOUTH DAKOTA
# 1               PLANKINTON 5.8 S  SOUTH DAKOTA
# 2               STICKNEY 0.2 SSE  SOUTH DAKOTA
# 3              WHITE LAKE 10.9 S  SOUTH DAKOTA
# 4               STICKNEY 5.4 SSW  SOUTH DAKOTA

# %%
stations_lookup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68512 entries, 0 to 68511
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_id    68512 non-null  object
#  1   latitude      68512 non-null  float64
#  2   longitude     68512 non-null  float64
#  3   elevation     68512 non-null  float64
#  4   state_code    68512 non-null  object
#  5   station_name  68512 non-null  object
#  6   state_name    68512 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 4.2+ MB

# %%
df = pd.read_csv("../data/raw_station_data/2021.csv", names=["station_id", "date", "metric", "value", "measurement_flag", "quality_flag", "source_flag", "observation_time"] )
df.head()
# Out:
# /Users/sanilveeravu/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     station_id      date metric  value measurement_flag quality_flag  \
# 0  AE000041196  20210101   TMAX    278              NaN          NaN
# 1  AE000041196  20210101   PRCP      0                D          NaN
# 2  AE000041196  20210101   TAVG    214                H          NaN
# 3  AEM00041194  20210101   TMAX    266              NaN          NaN
# 4  AEM00041194  20210101   TMIN    178              NaN          NaN
#
#   source_flag  observation_time
# 0           S               NaN
# 1           S               NaN
# 2           S               NaN
# 3           S               NaN
# 4           S               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35917674 entries, 0 to 35917673
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   station_id        object
#  1   date              int64
#  2   metric            object
#  3   value             int64
#  4   measurement_flag  object
#  5   quality_flag      object
#  6   source_flag       object
#  7   observation_time  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.1+ GB

# %%
df = df[df.metric == "TMAX"]
df.head()
# Out:
#       station_id      date metric  value measurement_flag quality_flag  \
# 0    AE000041196  20210101   TMAX    278              NaN          NaN
# 3    AEM00041194  20210101   TMAX    266              NaN          NaN
# 7    AEM00041217  20210101   TMAX    262              NaN          NaN
# 10   AEM00041218  20210101   TMAX    250              NaN          NaN
# 136  AJ000037575  20210101   TMAX      4              NaN          NaN
#
#     source_flag  observation_time
# 0             S               NaN
# 3             S               NaN
# 7             S               NaN
# 10            S               NaN
# 136           S               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4107543 entries, 0 to 35917670
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   station_id        object
#  1   date              int64
#  2   metric            object
#  3   value             int64
#  4   measurement_flag  object
#  5   quality_flag      object
#  6   source_flag       object
#  7   observation_time  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 282.0+ MB

# %%
df = df[df.station_id.str[:2] == "US"]
df.head()
# Out:
#         station_id      date metric  value measurement_flag quality_flag  \
# 45021  USC00010063  20210101   TMAX    189              NaN          NaN
# 45026  USC00010160  20210101   TMAX    189              NaN          NaN
# 45031  USC00010178  20210101   TMAX    211              NaN          NaN
# 45037  USC00010260  20210101   TMAX    206              NaN          NaN
# 45043  USC00010390  20210101   TMAX    228              NaN          NaN
#
#       source_flag  observation_time
# 45021           7             630.0
# 45026           7             700.0
# 45031           7            1000.0
# 45037           7            1800.0
# 45043           7            2400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2599277 entries, 45021 to 35917434
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   station_id        object
#  1   date              int64
#  2   metric            object
#  3   value             int64
#  4   measurement_flag  object
#  5   quality_flag      object
#  6   source_flag       object
#  7   observation_time  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 178.5+ MB

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')

# %%
df.head()
# Out:
#         station_id       date metric  value measurement_flag quality_flag  \
# 45021  USC00010063 2021-01-01   TMAX    189              NaN          NaN
# 45026  USC00010160 2021-01-01   TMAX    189              NaN          NaN
# 45031  USC00010178 2021-01-01   TMAX    211              NaN          NaN
# 45037  USC00010260 2021-01-01   TMAX    206              NaN          NaN
# 45043  USC00010390 2021-01-01   TMAX    228              NaN          NaN
#
#       source_flag  observation_time
# 45021           7             630.0
# 45026           7             700.0
# 45031           7            1000.0
# 45037           7            1800.0
# 45043           7            2400.0

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['day'] = pd.DatetimeIndex(df['date']).day
df.head()
# Out:
#         station_id       date metric  value measurement_flag quality_flag  \
# 45021  USC00010063 2021-01-01   TMAX    189              NaN          NaN
# 45026  USC00010160 2021-01-01   TMAX    189              NaN          NaN
# 45031  USC00010178 2021-01-01   TMAX    211              NaN          NaN
# 45037  USC00010260 2021-01-01   TMAX    206              NaN          NaN
# 45043  USC00010390 2021-01-01   TMAX    228              NaN          NaN
#
#       source_flag  observation_time  year  month  day
# 45021           7             630.0  2021      1    1
# 45026           7             700.0  2021      1    1
# 45031           7            1000.0  2021      1    1
# 45037           7            1800.0  2021      1    1
# 45043           7            2400.0  2021      1    1

# %%
df.drop(["date","measurement_flag","quality_flag","source_flag","observation_time"], axis=1, inplace=True)

# %%
df["value"] = df.value / 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2599277 entries, 45021 to 35917434
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   station_id  object
#  1   metric      object
#  2   value       float64
#  3   year        int64
#  4   month       int64
#  5   day         int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 138.8+ MB

# %%
# df = df.join(stations_df, type="inner")
df = pd.merge(df, stations_df, how='inner', on = 'station_id')

# %%
df.head()
# Out:
#     station_id metric  value  year  month  day  latitude  longitude  \
# 0  USC00010063   TMAX   18.9  2021      1    1   34.2553   -87.1814
# 1  USC00010063   TMAX   21.7  2021      1    2   34.2553   -87.1814
# 2  USC00010063   TMAX   13.3  2021      1    3   34.2553   -87.1814
# 3  USC00010063   TMAX   13.3  2021      1    5   34.2553   -87.1814
# 4  USC00010063   TMAX   10.6  2021      1    6   34.2553   -87.1814
#
#    elevation state_code station_name
# 0      249.3         AL      ADDISON
# 1      249.3         AL      ADDISON
# 2      249.3         AL      ADDISON
# 3      249.3         AL      ADDISON
# 4      249.3         AL      ADDISON

# %%
df = df.groupby(["state_code", "year", "month", "day"]).agg("max").reset_index()
df.head()
# Out:
#   state_code  year  month  day   station_id metric  value  latitude  \
# 0         AK  2021      1    1  USW00096409   TMAX    6.7   71.3244
# 1         AK  2021      1    2  USW00096409   TMAX    7.2   71.3244
# 2         AK  2021      1    3  USW00096409   TMAX    7.2   71.3244
# 3         AK  2021      1    4  USW00096409   TMAX    8.3   71.3244
# 4         AK  2021      1    5  USW00096409   TMAX    7.2   71.3244
#
#    longitude  elevation    station_name
# 0   170.2222      944.9  ZAREMBO ALASKA
# 1   170.2222      944.9  ZAREMBO ALASKA
# 2   170.2222      944.9  ZAREMBO ALASKA
# 3   170.2222      944.9  ZAREMBO ALASKA
# 4   170.2222      944.9  ZAREMBO ALASKA

# %%
df.state_code.value_counts()
# Out:
# AK    365
# PA    365
# ND    365
# NE    365
# NH    365
# NJ    365
# NM    365
# NV    365
# NY    365
# OH    365
# OK    365
# OR    365
# RI    365
# AL    365
# SC    365
# SD    365
# TN    365
# TX    365
# UT    365
# VA    365
# VT    365
# WA    365
# WI    365
# WV    365
# NC    365
# MT    365
# MS    365
# MO    365
# AR    365
# AZ    365
# CA    365
# CO    365
# CT    365
# DE    365
# FL    365
# GA    365
# HI    365
# IA    365
# ID    365
# IL    365
# IN    365
# KS    365
# KY    365
# LA    365
# MA    365
# MD    365
# ME    365
# MI    365
# MN    365
# WY    365
# Name: state_code, dtype: int64

# %%
df.shape
# Out:
# (18250, 11)
