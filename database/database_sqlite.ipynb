# %%
from sqlalchemy import create_engine, inspect
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = "../data/cleaned_data/tmaxdata_max_with_lat_long_yearly.csv"
tmax_df = pd.read_csv(data)
tmax_df.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01   36.1     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01   36.1     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01   37.8     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01   31.7     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01   34.4     Alaska  66.160507 -153.369141

# %%
data = "../data/cleaned_data/tmindata_min_with_lat_long_yearly.csv"
tmin_df = pd.read_csv(data)
tmin_df.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  -52.8     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  -58.9     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  -54.4     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  -54.4     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  -56.1     Alaska  66.160507 -153.369141

# %%
data = "../data/cleaned_data/snowdata_max_with_lat_long_yearly.csv"
snow_df = pd.read_csv(data)
snow_df.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  483.0     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  521.0     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  635.0     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  660.0     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  775.0     Alaska  66.160507 -153.369141

# %%
data = "../data/cleaned_data/prcpdata_max_with_lat_long_yearly.csv"
prcp_df = pd.read_csv(data)
prcp_df.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  120.7     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  103.1     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  136.1     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  254.0     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  203.2     Alaska  66.160507 -153.369141

# %%
database_path = "weather.sqlite"
conn_string = f"sqlite:///{database_path}"

# Create an engine that can talk to the database
engine = create_engine(conn_string)

# %%
def create_metric_table(metric_name): 
    sql=f""" CREATE TABLE {metric_name} (
        state_code varchar,
        date int,
        value float,
        state_name varchar,
        latitude float,
        longitude float
    )"""
    engine.execute(sql)

# %%
create_metric_table("tmax")
create_metric_table("tmin")
create_metric_table("snow")
create_metric_table("prcp")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# OperationalError: table tmax already exists
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6700/2729845156.py in <module>
# ----> 1 create_metric_table("tmax")
#       2 create_metric_table("tmin")
#       3 create_metric_table("snow")
#       4 create_metric_table("prcp")
#       5
#
# ~\AppData\Local\Temp/ipykernel_6700/2596298235.py in create_metric_table(metric_name)
#       8         longitude float
#       9     )"""
# ---> 10     engine.execute(sql)
#
# <string> in execute(self, statement, *multiparams, **params)
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3106         """
#    3107         connection = self.connect(close_with_result=True)
# -> 3108         return connection.execute(statement, *multiparams, **params)
#    3109
#    3110     @util.deprecated_20(
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1251                 params,
#    1252                 _EMPTY_EXECUTION_OPTS,
# -> 1253                 future=False,
#    1254             )
#    1255
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1552             execution_options,
#    1553             statement,
# -> 1554             distilled_parameters,
#    1555         )
#    1556
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1813         except BaseException as e:
#    1814             self._handle_dbapi_exception(
# -> 1815                 e, statement, parameters, cursor, context
#    1816             )
#    1817
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1994             elif should_wrap:
#    1995                 util.raise_(
# -> 1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#    1998             else:
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#    1774
#
# c:\Users\carml\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) table tmax already exists
# [SQL:  CREATE TABLE tmax (
#         state_code varchar,
#         date int,
#         value float,
#         state_name varchar,
#         latitude float,
#         longitude float
#     )]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
 # get all tables
inspector_gadget = inspect(engine)
tables = inspector_gadget.get_table_names()
for table in tables:
    print(table)
    
    # get all columns in table
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column)
    print()
# Out:
# prcp
# {'name': 'state_code', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'value', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'state_name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'latitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'longitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# snow
# {'name': 'state_code', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'value', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'state_name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'latitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'longitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# tmax
# {'name': 'state_code', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'value', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'state_name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'latitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'longitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# tmin
# {'name': 'state_code', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'value', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'state_name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'latitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'longitude', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
tmax_df.to_sql("tmax", con=engine, method="multi", index=False, if_exists="replace")

# %%
tmin_df.to_sql("tmin", con=engine, method="multi", index=False, if_exists="replace")
snow_df.to_sql("snow", con=engine, method="multi", index=False, if_exists="replace")
prcp_df.to_sql("prcp", con=engine, method="multi", index=False, if_exists="replace")

# %%
conn = engine.connect()

query = """
        SELECT 
             *
        fROM
            TMAX;
        """
tmax_final = pd.read_sql(query, conn)
tmax_final.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01   36.1     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01   36.1     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01   37.8     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01   31.7     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01   34.4     Alaska  66.160507 -153.369141

# %%
conn = engine.connect()

query = """
        SELECT 
             *
        fROM
            TMIN;
        """
tmin_final = pd.read_sql(query, conn)
tmin_final.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  -52.8     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  -58.9     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  -54.4     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  -54.4     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  -56.1     Alaska  66.160507 -153.369141

# %%
conn = engine.connect()

query = """
        SELECT 
             *
        fROM
            SNOW;
        """
snow_final = pd.read_sql(query, conn)
snow_final.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  483.0     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  521.0     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  635.0     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  660.0     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  775.0     Alaska  66.160507 -153.369141

# %%
conn = engine.connect()

query = """
        SELECT 
             *
        fROM
            prcp;
        """
prcp_final = pd.read_sql(query, conn)
prcp_final.head()
# Out:
#   state_code        date  value state_name   latitude   longitude
# 0         AK  1905-01-01  120.7     Alaska  66.160507 -153.369141
# 1         AK  1906-01-01  103.1     Alaska  66.160507 -153.369141
# 2         AK  1907-01-01  136.1     Alaska  66.160507 -153.369141
# 3         AK  1908-01-01  254.0     Alaska  66.160507 -153.369141
# 4         AK  1909-01-01  203.2     Alaska  66.160507 -153.369141
